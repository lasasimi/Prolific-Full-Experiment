# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
all_apps = pd.read_csv('Lasmi15dec.csv')
all_apps.columns
# Out:
# Index(['participant.id_in_session', 'participant.code', 'participant.label',
#        'participant._is_bot', 'participant._index_in_pages',
#        'participant._max_page_index', 'participant._current_app_name',
#        'participant._current_page_name', 'participant.time_started_utc',
#        'participant.visited',
#        ...
#        'noPay.1.player.feedback_final', 'noPay.1.group.id_in_subsession',
#        'noPay.1.subsession.round_number', 'Pay.1.player.id_in_group',
#        'Pay.1.player.role', 'Pay.1.player.payoff',
#        'Pay.1.player.feedback_final', 'Pay.1.player.future_participation',
#        'Pay.1.group.id_in_subsession', 'Pay.1.subsession.round_number'],
#       dtype='object', length=625)

# %%
len(all_apps.loc[all_apps['mock.2.player.discussion_grp']== all_apps['mock.18.player.discussion_grp']]['participant.code'])
# Out:
# 20

# %%
all_apps[['participant.code','presurvey.1.player.response','mock.2.player.discussion_grp']]
# Out:
#    participant.code  presurvey.1.player.response  \
# 0          csr0gln2                            1
# 1          t0hpl3vv                           -1
# 2          8yoizl44                            1
# 3          big6jwq4                           -1
# 4          90b2dg40                            1
# 5          doojahws                           -1
# 6          4cd3z4c3                            1
# 7          fz1hgpq4                           -1
# 8          xyne8ou9                            1
# 9          59ktc1rr                           -1
# 10         x3cx6d8q                            1
# 11         guqnj7bx                           -1
# 12         5gi81nte                            1
# 13         thf58hs8                           -1
# 14         g7igh3rf                            1
# 15         hb13kr1c                           -1
# 16         kyubaibd                            1
# 17         s1bz3kze                           -1
# ...
